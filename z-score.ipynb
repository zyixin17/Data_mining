# %%
import numpy as np
import pandas as pd

weather = pd.read_csv('./weather_Final.csv')
weather.head()
# Out:
#    Unnamed: 0  Year  Month  day  temp_max  temp_avg  temp_min  dewp_max  \
# 0         732  2019      1    1        63      57.8        51        59
# 1         733  2019      1    2        53      50.6        48        51
# 2         734  2019      1    3        55      52.1        50        54
# 3         735  2019      1    4        62      52.6        43        59
# 4         736  2019      1    5        60      45.9        40        40
#
#    dewp_avg  dewp_min  ...  wind_max  wind_avg  wind_min  pres_max  pres_avg  \
# 0      54.4        50  ...         8       3.6         0      29.5      29.5
# 1      49.0        48  ...         9       4.5         0      29.6      29.5
# 2      50.4        48  ...        14       5.5         0      29.4      29.3
# 3      48.4        40  ...        23      13.6         6      29.3      29.1
# 4      38.1        35  ...        16       7.2         0      29.5      29.4
#
#    pres_min  prec      Time  DTR  weather
# ...

# %%
import scipy.stats as stats
data = pd.DataFrame(weather, columns=['temp_max', 'temp_avg', 'temp_min','dewp_max','dewp_min','pres_max','pres_min','pres_avg','prec','DTR'])
data.apply(stats.zscore)
# Out:
#       temp_max  temp_avg  temp_min  dewp_max  dewp_min  pres_max  pres_min  \
# 0    -0.839946 -0.498015 -0.248761  0.051158  0.154011  0.192862  0.120519
# 1    -1.555557 -1.012066 -0.434781 -0.524436  0.039430  0.895751  0.120519
# 2    -1.412435 -0.904972 -0.310768 -0.308588  0.039430 -0.510027  0.048880
# 3    -0.911507 -0.869274 -0.744814  0.051158 -0.418897 -1.212916 -0.022759
# 4    -1.054629 -1.347627 -0.930834 -1.315877 -0.705351  0.192862  0.084700
# ...        ...       ...       ...       ...       ...       ...       ...
# 1092 -0.052774  0.280202  0.619331  0.410904  0.784210 -0.510027  0.048880
# 1093  0.090348  0.337318  0.557325  0.698701  0.898792 -1.915805  0.013061
# 1094  0.161909  0.430133  0.681338  0.842600  0.898792 -1.915805  0.013061
# 1095  0.018787  0.073153  0.061272  0.770650  0.497756 -1.212916  0.048880
# 1096 -0.195896  0.430133  0.929365  0.770650  1.185246 -1.915805  0.048880
#
#       pres_avg      prec       DTR
# ...

# %%
weather
# Out:
#       Unnamed: 0  Year  Month  day  temp_max  temp_avg  temp_min  dewp_max  \
# 0            732  2019      1    1        63      57.8        51        59
# 1            733  2019      1    2        53      50.6        48        51
# 2            734  2019      1    3        55      52.1        50        54
# 3            735  2019      1    4        62      52.6        43        59
# 4            736  2019      1    5        60      45.9        40        40
# ...          ...   ...    ...  ...       ...       ...       ...       ...
# 1092         362  2021     12   27        74      68.7        65        64
# 1093         363  2021     12   28        76      69.5        64        68
# 1094         364  2021     12   29        77      70.8        66        70
# 1095         365  2021     12   30        75      65.8        56        69
# 1096         366  2021     12   31        72      70.8        70        69
#
# ...
